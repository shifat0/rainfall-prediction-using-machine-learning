# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
dataset = pd.read_csv('65 Years of Weather Data Bangladesh (1948 - 2013).csv')
dataset
# Out:
#        Unnamed: 0 Station Names  YEAR  Month  Max Temp  Min Temp  Rainfall  \
# 0               0       Barisal  1949      1      29.4      12.3       0.0
# 1               1       Barisal  1950      1      30.0      14.1       0.0
# 2               2       Barisal  1951      1      28.2      12.3       0.0
# 3               3       Barisal  1952      1      26.6      12.3       2.0
# 4               4       Barisal  1953      1      30.0      13.3      10.0
# ...           ...           ...   ...    ...       ...       ...       ...
# 21115       21115        Teknaf  2009     12      30.3      16.5       0.0
# 21116       21116        Teknaf  2010     12      31.7      16.7     193.0
# 21117       21117        Teknaf  2011     12      31.5      16.4       0.0
# 21118       21118        Teknaf  2012     12      30.0      15.8       0.0
# 21119       21119        Teknaf  2013     12      29.9      16.5       0.0
#
#        Relative Humidity  Wind Speed  Cloud Coverage  Bright Sunshine  \
# 0                   68.0    0.453704             0.6         7.831915
# 1                   77.0    0.453704             0.8         7.831915
# 2                   77.0    0.453704             0.6         7.831915
# 3                   77.0    0.453704             1.0         7.831915
# 4                   75.0    0.453704             1.6         7.831915
# ...                  ...         ...             ...              ...
# 21115               72.0    2.800000             0.9         8.700000
# 21116               79.0    2.400000             1.4         5.500000
# 21117               73.0    0.000000             1.5         7.400000
# 21118               70.0    1.800000             0.2         9.000000
# 21119               72.0    3.000000             0.9         8.100000
#
#        Station Number     X_COR     Y_COR  LATITUDE  LONGITUDE  ALT   Period
# 0               41950  536809.8  510151.9     22.70      90.36    4  1949.01
# 1               41950  536809.8  510151.9     22.70      90.36    4  1950.01
# 2               41950  536809.8  510151.9     22.70      90.36    4  1951.01
# 3               41950  536809.8  510151.9     22.70      90.36    4  1952.01
# 4               41950  536809.8  510151.9     22.70      90.36    4  1953.01
# ...               ...       ...       ...       ...        ...  ...      ...
# 21115           41998  734765.4  308914.1     20.87      92.26    4  2009.12
# 21116           41998  734765.4  308914.1     20.87      92.26    4  2010.12
# 21117           41998  734765.4  308914.1     20.87      92.26    4  2011.12
# 21118           41998  734765.4  308914.1     20.87      92.26    4  2012.12
# 21119           41998  734765.4  308914.1     20.87      92.26    4  2013.12
#
# [21120 rows x 18 columns]

# %%
#adding units in column names
column = ['Unnamed: 0', 'Station Names', 'YEAR', 'Month', 'Max Temp 0 C',
       'Min Temp 0 C', 'Rainfall (mm)', 'Relative Humidity %',
       'Wind Speed (m/s)', 'Cloud Coverage %', 'Bright Sunshine (Hours)',
       'Station Number', 'X_COR', 'Y_COR', 'LATITUDE', 'LONGITUDE', 'ALT',
       'Period']

# %%
dataset.columns = column
dataset
# Out:
#        Unnamed: 0 Station Names  YEAR  Month  Max Temp 0 C  Min Temp 0 C  \
# 0               0       Barisal  1949      1          29.4          12.3
# 1               1       Barisal  1950      1          30.0          14.1
# 2               2       Barisal  1951      1          28.2          12.3
# 3               3       Barisal  1952      1          26.6          12.3
# 4               4       Barisal  1953      1          30.0          13.3
# ...           ...           ...   ...    ...           ...           ...
# 21115       21115        Teknaf  2009     12          30.3          16.5
# 21116       21116        Teknaf  2010     12          31.7          16.7
# 21117       21117        Teknaf  2011     12          31.5          16.4
# 21118       21118        Teknaf  2012     12          30.0          15.8
# 21119       21119        Teknaf  2013     12          29.9          16.5
#
#        Rainfall (mm)  Relative Humidity %  Wind Speed (m/s)  Cloud Coverage %  \
# 0                0.0                 68.0          0.453704               0.6
# 1                0.0                 77.0          0.453704               0.8
# 2                0.0                 77.0          0.453704               0.6
# 3                2.0                 77.0          0.453704               1.0
# 4               10.0                 75.0          0.453704               1.6
# ...              ...                  ...               ...               ...
# 21115            0.0                 72.0          2.800000               0.9
# 21116          193.0                 79.0          2.400000               1.4
# 21117            0.0                 73.0          0.000000               1.5
# 21118            0.0                 70.0          1.800000               0.2
# 21119            0.0                 72.0          3.000000               0.9
#
#        Bright Sunshine (Hours)  Station Number     X_COR     Y_COR  LATITUDE  \
# 0                     7.831915           41950  536809.8  510151.9     22.70
# 1                     7.831915           41950  536809.8  510151.9     22.70
# 2                     7.831915           41950  536809.8  510151.9     22.70
# 3                     7.831915           41950  536809.8  510151.9     22.70
# 4                     7.831915           41950  536809.8  510151.9     22.70
# ...                        ...             ...       ...       ...       ...
# 21115                 8.700000           41998  734765.4  308914.1     20.87
# 21116                 5.500000           41998  734765.4  308914.1     20.87
# 21117                 7.400000           41998  734765.4  308914.1     20.87
# 21118                 9.000000           41998  734765.4  308914.1     20.87
# 21119                 8.100000           41998  734765.4  308914.1     20.87
#
#        LONGITUDE  ALT   Period
# 0          90.36    4  1949.01
# 1          90.36    4  1950.01
# 2          90.36    4  1951.01
# 3          90.36    4  1952.01
# 4          90.36    4  1953.01
# ...          ...  ...      ...
# 21115      92.26    4  2009.12
# 21116      92.26    4  2010.12
# 21117      92.26    4  2011.12
# 21118      92.26    4  2012.12
# 21119      92.26    4  2013.12
#
# [21120 rows x 18 columns]

# %% [markdown]
# ## EDA & Feature Engineering

# %%
#Checking Correlation of features with rainfall
dataset.corr() ['Rainfall (mm)']
# Out:
# Unnamed: 0                 0.064153
# YEAR                       0.025109
# Month                      0.132680
# Max Temp 0 C               0.256821
# Min Temp 0 C               0.596625
# Rainfall (mm)              1.000000
# Relative Humidity %        0.591049
# Wind Speed (m/s)           0.316366
# Cloud Coverage %           0.766821
# Bright Sunshine (Hours)   -0.673333
# Station Number             0.113804
# X_COR                      0.167625
# Y_COR                     -0.066154
# LATITUDE                  -0.105569
# LONGITUDE                  0.197805
# ALT                       -0.009696
# Period                     0.025369
# Name: Rainfall (mm), dtype: float64

# %%
#Drop Features that have very negligible correlation with data
dataset = dataset.drop(['Station Names','Unnamed: 0','YEAR','Max Temp 0 C','X_COR','Y_COR','LATITUDE','LONGITUDE','ALT','Period'],axis =1)
dataset
# Out:
#        Month  Min Temp 0 C  Rainfall (mm)  Relative Humidity %  \
# 0          1          12.3            0.0                 68.0
# 1          1          14.1            0.0                 77.0
# 2          1          12.3            0.0                 77.0
# 3          1          12.3            2.0                 77.0
# 4          1          13.3           10.0                 75.0
# ...      ...           ...            ...                  ...
# 21115     12          16.5            0.0                 72.0
# 21116     12          16.7          193.0                 79.0
# 21117     12          16.4            0.0                 73.0
# 21118     12          15.8            0.0                 70.0
# 21119     12          16.5            0.0                 72.0
#
#        Wind Speed (m/s)  Cloud Coverage %  Bright Sunshine (Hours)  \
# 0              0.453704               0.6                 7.831915
# 1              0.453704               0.8                 7.831915
# 2              0.453704               0.6                 7.831915
# 3              0.453704               1.0                 7.831915
# 4              0.453704               1.6                 7.831915
# ...                 ...               ...                      ...
# 21115          2.800000               0.9                 8.700000
# 21116          2.400000               1.4                 5.500000
# 21117          0.000000               1.5                 7.400000
# 21118          1.800000               0.2                 9.000000
# 21119          3.000000               0.9                 8.100000
#
#        Station Number
# 0               41950
# 1               41950
# 2               41950
# 3               41950
# 4               41950
# ...               ...
# 21115           41998
# 21116           41998
# 21117           41998
# 21118           41998
# 21119           41998
#
# [21120 rows x 8 columns]

# %%
#Checking null values in dataset
dataset. isnull().sum()
# Out:
# Month                      0
# Min Temp 0 C               0
# Rainfall (mm)              0
# Relative Humidity %        0
# Wind Speed (m/s)           0
# Cloud Coverage %           0
# Bright Sunshine (Hours)    0
# Station Number             0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['Month', 'Min Temp 0 C', 'Rainfall (mm)', 'Relative Humidity %',
#        'Wind Speed (m/s)', 'Cloud Coverage %', 'Bright Sunshine (Hours)',
#        'Station Number'],
#       dtype='object')

# %%
#Removing Outliars
from scipy import stats
dataset = dataset[(np.abs(stats.zscore(dataset)) < 3).all(axis=1)]
dataset = dataset.reset_index(drop = True)
dataset
# Out:
#        Month  Min Temp 0 C  Rainfall (mm)  Relative Humidity %  \
# 0          1          12.3            0.0                 68.0
# 1          1          14.1            0.0                 77.0
# 2          1          12.3            0.0                 77.0
# 3          1          12.3            2.0                 77.0
# 4          1          13.3           10.0                 75.0
# ...      ...           ...            ...                  ...
# 20222     12          16.5            0.0                 72.0
# 20223     12          16.7          193.0                 79.0
# 20224     12          16.4            0.0                 73.0
# 20225     12          15.8            0.0                 70.0
# 20226     12          16.5            0.0                 72.0
#
#        Wind Speed (m/s)  Cloud Coverage %  Bright Sunshine (Hours)  \
# 0              0.453704               0.6                 7.831915
# 1              0.453704               0.8                 7.831915
# 2              0.453704               0.6                 7.831915
# 3              0.453704               1.0                 7.831915
# 4              0.453704               1.6                 7.831915
# ...                 ...               ...                      ...
# 20222          2.800000               0.9                 8.700000
# 20223          2.400000               1.4                 5.500000
# 20224          0.000000               1.5                 7.400000
# 20225          1.800000               0.2                 9.000000
# 20226          3.000000               0.9                 8.100000
#
#        Station Number
# 0               41950
# 1               41950
# 2               41950
# 3               41950
# 4               41950
# ...               ...
# 20222           41998
# 20223           41998
# 20224           41998
# 20225           41998
# 20226           41998
#
# [20227 rows x 8 columns]

# %%
dataset.isnull().sum()
# Out:
# Month                      0
# Min Temp 0 C               0
# Rainfall (mm)              0
# Relative Humidity %        0
# Wind Speed (m/s)           0
# Cloud Coverage %           0
# Bright Sunshine (Hours)    0
# Station Number             0
# dtype: int64

# %%
plt.figure(figsize=(10, 8))
x = dataset['Relative Humidity %']
y = dataset['Rainfall (mm)']
plt.scatter(x, y, color='red')
plt.title("Relative Humidity % vs Rainfall (mm)")
plt.xlabel("Relative Humidity %")
plt.ylabel("Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
x = dataset['Min Temp 0 C']
y = dataset['Rainfall (mm)']
plt.scatter(x, y, color='skyblue')
plt.title("Min Temp 0 C vs Rainfall (mm)")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
x = dataset['Month']
y = dataset['Rainfall (mm)']
plt.scatter(x, y, color='green')
plt.title("Month vs Rainfall (mm)")
plt.xlabel("Month")
plt.ylabel("Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
x = dataset['Wind Speed (m/s)']
y = dataset['Rainfall (mm)']
plt.scatter(x, y, color='orange')
plt.title("Wind Speed (m/s) vs Rainfall (mm)")
plt.xlabel("Wind Speed (m/s)")
plt.ylabel("Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
x = dataset['Bright Sunshine (Hours)']
y = dataset['Rainfall (mm)']
plt.scatter(x, y, color='purple')
plt.title("Bright Sunshine (Hours) vs Rainfall (mm)")
plt.xlabel("Bright Sunshine (Hours)")
plt.ylabel("Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
x = dataset['Cloud Coverage %']
y = dataset['Rainfall (mm)']
plt.scatter(x, y, color='Grey')
plt.title("Cloud Coverage % vs Rainfall (mm)")
plt.xlabel("Cloud Coverage %")
plt.ylabel("Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
x = dataset['Station Number']
y = dataset['Rainfall (mm)']
plt.scatter(x, y, color='violet')
plt.title("Station Number vs Rainfall (mm)")
plt.xlabel("Station Number")
plt.ylabel("Rainfall (mm)")
plt.show()

# %% [markdown]
# # Data Normalization

# %%
D = dataset[['Month', 'Min Temp 0 C', 'Relative Humidity %', 'Wind Speed (m/s)',
      'Cloud Coverage %', 'Bright Sunshine (Hours)', 'Station Number']]
D
# Out:
#        Month  Min Temp 0 C  Relative Humidity %  Wind Speed (m/s)  \
# 0          1          12.3                 68.0          0.453704
# 1          1          14.1                 77.0          0.453704
# 2          1          12.3                 77.0          0.453704
# 3          1          12.3                 77.0          0.453704
# 4          1          13.3                 75.0          0.453704
# ...      ...           ...                  ...               ...
# 20222     12          16.5                 72.0          2.800000
# 20223     12          16.7                 79.0          2.400000
# 20224     12          16.4                 73.0          0.000000
# 20225     12          15.8                 70.0          1.800000
# 20226     12          16.5                 72.0          3.000000
#
#        Cloud Coverage %  Bright Sunshine (Hours)  Station Number
# 0                   0.6                 7.831915           41950
# 1                   0.8                 7.831915           41950
# 2                   0.6                 7.831915           41950
# 3                   1.0                 7.831915           41950
# 4                   1.6                 7.831915           41950
# ...                 ...                      ...             ...
# 20222               0.9                 8.700000           41998
# 20223               1.4                 5.500000           41998
# 20224               1.5                 7.400000           41998
# 20225               0.2                 9.000000           41998
# 20226               0.9                 8.100000           41998
#
# [20227 rows x 7 columns]

# %%
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

# %%
scale.fit(D)
# Out:
# StandardScaler()

# %%
scaled_data = scale.transform(D)
A = pd.DataFrame(scaled_data)
A.columns =['Month', 'Min Temp 0 C', 'Relative Humidity %', 'Wind Speed (m/s)','Cloud Coverage %', 'Bright Sunshine (Hours)', 'Station Number']
# E = scale.inverse_transform(scaled_data)
# E = pd.DataFrame(E)
A['Rainfall (mm)'] = dataset['Rainfall (mm)']
A
# Out:
#           Month  Min Temp 0 C  Relative Humidity %  Wind Speed (m/s)  \
# 0     -1.585893     -1.753679            -1.631477         -0.985110
# 1     -1.585893     -1.393738            -0.364032         -0.985110
# 2     -1.585893     -1.753679            -0.364032         -0.985110
# 3     -1.585893     -1.753679            -0.364032         -0.985110
# 4     -1.585893     -1.553712            -0.645686         -0.985110
# ...         ...           ...                  ...               ...
# 20222  1.562671     -0.913818            -1.068168          1.626681
# 20223  1.562671     -0.873825            -0.082377          1.181419
# 20224  1.562671     -0.933815            -0.927340         -1.490153
# 20225  1.562671     -1.053795            -1.349822          0.513526
# 20226  1.562671     -0.913818            -1.068168          1.849312
#
#        Cloud Coverage %  Bright Sunshine (Hours)  Station Number  \
# 0             -1.377608                 0.813194        0.451560
# 1             -1.280212                 0.813194        0.451560
# 2             -1.377608                 0.813194        0.451560
# 3             -1.182816                 0.813194        0.451560
# 4             -0.890628                 0.813194        0.451560
# ...                 ...                      ...             ...
# 20222         -1.231514                 1.325613        1.761501
# 20223         -0.988024                -0.563303        1.761501
# 20224         -0.939326                 0.558241        1.761501
# 20225         -1.572400                 1.502699        1.761501
# 20226         -1.231514                 0.971441        1.761501
#
#        Rainfall (mm)
# 0                0.0
# 1                0.0
# 2                0.0
# 3                2.0
# 4               10.0
# ...              ...
# 20222            0.0
# 20223          193.0
# 20224            0.0
# 20225            0.0
# 20226            0.0
#
# [20227 rows x 8 columns]

# %%
A.isnull().sum()
# Out:
# Month                      0
# Min Temp 0 C               0
# Relative Humidity %        0
# Wind Speed (m/s)           0
# Cloud Coverage %           0
# Bright Sunshine (Hours)    0
# Station Number             0
# Rainfall (mm)              0
# dtype: int64

# %%
data = dataset
dataset = A
dataset
# Out:
#           Month  Min Temp 0 C  Relative Humidity %  Wind Speed (m/s)  \
# 0     -1.585893     -1.753679            -1.631477         -0.985110
# 1     -1.585893     -1.393738            -0.364032         -0.985110
# 2     -1.585893     -1.753679            -0.364032         -0.985110
# 3     -1.585893     -1.753679            -0.364032         -0.985110
# 4     -1.585893     -1.553712            -0.645686         -0.985110
# ...         ...           ...                  ...               ...
# 20222  1.562671     -0.913818            -1.068168          1.626681
# 20223  1.562671     -0.873825            -0.082377          1.181419
# 20224  1.562671     -0.933815            -0.927340         -1.490153
# 20225  1.562671     -1.053795            -1.349822          0.513526
# 20226  1.562671     -0.913818            -1.068168          1.849312
#
#        Cloud Coverage %  Bright Sunshine (Hours)  Station Number  \
# 0             -1.377608                 0.813194        0.451560
# 1             -1.280212                 0.813194        0.451560
# 2             -1.377608                 0.813194        0.451560
# 3             -1.182816                 0.813194        0.451560
# 4             -0.890628                 0.813194        0.451560
# ...                 ...                      ...             ...
# 20222         -1.231514                 1.325613        1.761501
# 20223         -0.988024                -0.563303        1.761501
# 20224         -0.939326                 0.558241        1.761501
# 20225         -1.572400                 1.502699        1.761501
# 20226         -1.231514                 0.971441        1.761501
#
#        Rainfall (mm)
# 0                0.0
# 1                0.0
# 2                0.0
# 3                2.0
# 4               10.0
# ...              ...
# 20222            0.0
# 20223          193.0
# 20224            0.0
# 20225            0.0
# 20226            0.0
#
# [20227 rows x 8 columns]

# %%
dataset.isnull().sum()
# Out:
# Month                      0
# Min Temp 0 C               0
# Relative Humidity %        0
# Wind Speed (m/s)           0
# Cloud Coverage %           0
# Bright Sunshine (Hours)    0
# Station Number             0
# Rainfall (mm)              0
# dtype: int64

# %% [markdown]
# # Splitting the dataset

# %%
from sklearn.model_selection import train_test_split

# %%
#Splitting the dataset into training & testing data
x, y = dataset[['Month', 'Min Temp 0 C', 'Relative Humidity %', 'Wind Speed (m/s)',
       'Cloud Coverage %', 'Bright Sunshine (Hours)', 'Station Number']], dataset[['Rainfall (mm)']]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#saving the split data index
a = x_train.index
b = x_test.index
training_index = pd.DataFrame(a)
testing_index = pd.DataFrame(b)

# %% [markdown]
# # Multiple Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
# define a fuction
Model_MLR=LinearRegression()
# fit the model with split dataset
Model_MLR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
Model_MLR.coef_
# Out:
# array([[ -6.23373569,  -3.96286447,  24.69773726,   7.16600062,
#         122.32201205, -35.01530663,  11.36562348]])

# %%
Model_MLR_prediction_test = Model_MLR.predict(x_test)
Model_MLR_prediction_train = Model_MLR.predict(x_train)

# %% [markdown]
# # Multiple Linear Regression Model Accuracy Check

# %%
Model_MLR_rmse_train = np.sqrt(mean_squared_error(y_train, Model_MLR_prediction_train))
Model_MLR_rmse_train
# Out:
# 118.32316154688014

# %%
Model_MLR_rmse_test = np.sqrt(mean_squared_error(y_test, Model_MLR_prediction_test))
Model_MLR_rmse_test
# Out:
# 118.27921788729373

# %%
Model_MLR_r2_train = r2_score(y_train, Model_MLR_prediction_train)
Model_MLR_r2_train
# Out:
# 0.6643429819595561

# %%
Model_MLR_r2_test = r2_score(y_test, Model_MLR_prediction_test)
Model_MLR_r2_test
# Out:
# 0.6687462139797271

# %%
MLR_result_train = data.iloc[training_index[0]]
MLR_result_train = MLR_result_train.reset_index(drop = True)
MLR_result_train['Predicted Rainfall (mm)'] = pd.DataFrame(Model_MLR_prediction_train)

MLR_result_test = data.iloc[testing_index[0]]
MLR_result_test = MLR_result_test.reset_index(drop = True)
MLR_result_test['Predicted Rainfall (mm)'] = pd.DataFrame(Model_MLR_prediction_test)

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(MLR_result_train['Min Temp 0 C'],MLR_result_train['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(MLR_result_train['Min Temp 0 C'],MLR_result_train['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(MLR_result_test['Min Temp 0 C'],MLR_result_test['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Test")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(MLR_result_test['Min Temp 0 C'],MLR_result_test['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Test")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %% [markdown]
# # Polynomial Regression Model

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=4, include_bias=True)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.fit_transform(x_test)

# %%
Model_PLR = LinearRegression()
Model_PLR.fit(x_train_poly, y_train)
# Out:
# LinearRegression()

# %%
Model_PLR_prediction_test = Model_PLR.predict(x_test_poly)
Model_PLR_prediction_train = Model_PLR.predict(x_train_poly)

# %% [markdown]
# # Polynomial Regression Model Accuracy Check

# %%
Model_PLR_rmse_train = np.sqrt(mean_squared_error(y_train, Model_PLR_prediction_train))
Model_PLR_rmse_train
# Out:
# 99.12397057543994

# %%
Model_PLR_rmse_test = np.sqrt(mean_squared_error(y_test, Model_PLR_prediction_test))
Model_PLR_rmse_test
# Out:
# 99.84420325947661

# %%
Model_PLR_r2_train = r2_score(y_train, Model_PLR_prediction_train)
Model_PLR_r2_train
# Out:
# 0.7644334716565548

# %%
Model_PLR_r2_test = r2_score(y_test, Model_PLR_prediction_test)
Model_PLR_r2_test
# Out:
# 0.7639577890590226

# %%
PLR_result_train = data.iloc[training_index[0]]
PLR_result_train = PLR_result_train.reset_index(drop = True)
PLR_result_train['Predicted Rainfall (mm)'] = pd.DataFrame(Model_PLR_prediction_train)

PLR_result_test = data.iloc[testing_index[0]]
PLR_result_test = PLR_result_test.reset_index(drop = True)
PLR_result_test['Predicted Rainfall (mm)'] = pd.DataFrame(Model_PLR_prediction_test)

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(PLR_result_train['Min Temp 0 C'],PLR_result_train['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(PLR_result_train['Min Temp 0 C'],PLR_result_train['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(PLR_result_test['Min Temp 0 C'],PLR_result_test['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Testing")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(PLR_result_test['Min Temp 0 C'],PLR_result_test['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Testing")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %% [markdown]
# # Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor # for building the model
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn import tree

# %%
Model_DT = DecisionTreeRegressor(criterion='mse',random_state = 0,max_depth= 7,splitter='best')
Model_DT.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=7, random_state=0)

# %%
Model_DT_prediction_test = Model_DT.predict(x_test)
Model_DT_prediction_train = Model_DT.predict(x_train)

# %% [markdown]
# # Decision Tree Model Accuracy Check

# %%
Model_DT_rmse_train = np.sqrt(mean_squared_error(y_train, Model_DT_prediction_train))
Model_DT_rmse_train
# Out:
# 101.19573725086131

# %%
Model_DT_rmse_test = np.sqrt(mean_squared_error(y_test, Model_DT_prediction_test))
Model_DT_rmse_test
# Out:
# 107.1371241793802

# %%
Model_DT_r2_train = r2_score(y_train, Model_DT_prediction_train)
Model_DT_r2_train
# Out:
# 0.7544835256835356

# %%
Model_DT_r2_test = r2_score(y_test, Model_DT_prediction_test)
Model_DT_r2_test
# Out:
# 0.728215971416367

# %%
DT_result_train = data.iloc[training_index[0]]
DT_result_train = DT_result_train.reset_index(drop = True)
DT_result_train['Predicted Rainfall (mm)'] = pd.DataFrame(Model_DT_prediction_train)

DT_result_test = data.iloc[testing_index[0]]
DT_result_test = DT_result_test.reset_index(drop = True)
DT_result_test['Predicted Rainfall (mm)'] = pd.DataFrame(Model_DT_prediction_test)

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(DT_result_train['Min Temp 0 C'],DT_result_train['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(DT_result_train['Min Temp 0 C'],DT_result_train['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(DT_result_test['Min Temp 0 C'],DT_result_test['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Test")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(DT_result_test['Min Temp 0 C'],DT_result_test['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Test")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %% [markdown]
# #  k-nearest neighbors Model

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
#Find the best value of hyper parameter
i = 1
k = 1
r = 0
while i<=100:
    Model_KNN = KNeighborsRegressor(i,weights='distance',algorithm='auto')
    Model_KNN.fit(x_train,y_train)
    y_prediction_test = Model_KNN.predict(x_test)
    r2 = r2_score(y_test, y_prediction_test)
    if r2> r:
        k=i
    i += i
print("Best Value of k is: " ,k)
# Out:
# Best Value of k is:  64

# %% [markdown]
# # k-nearest neighbors Model Accuracy Check

# %%
Model_KNN = KNeighborsRegressor(64,weights='distance',algorithm='auto')
Model_KNN.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=64, weights='distance')

# %%
Model_KNN_prediction_test = Model_KNN.predict(x_test)
Model_KNN_prediction_train = Model_KNN.predict(x_train)

# %%
Model_KNN_rmse_train = np.sqrt(mean_squared_error(y_train, Model_KNN_prediction_train))
Model_KNN_rmse_train
# Out:
# 5.58402443806174

# %%
Model_KNN_rmse_test = np.sqrt(mean_squared_error(y_test, Model_KNN_prediction_test))
Model_KNN_rmse_test
# Out:
# 103.32021558465446

# %%
Model_KNN_r2_train = r2_score(y_train, Model_KNN_prediction_train)
Model_KNN_r2_train
# Out:
# 0.999252431795161

# %%
Model_KNN_r2_test = r2_score(y_test, Model_KNN_prediction_test)
Model_KNN_r2_test
# Out:
# 0.7472363781096438

# %%
KNN_result_train = data.iloc[training_index[0]]
KNN_result_train = KNN_result_train.reset_index(drop = True)
KNN_result_train['Predicted Rainfall (mm)'] = pd.DataFrame(Model_KNN_prediction_train)

KNN_result_test = data.iloc[testing_index[0]]
KNN_result_test = KNN_result_test.reset_index(drop = True)
KNN_result_test['Predicted Rainfall (mm)'] = pd.DataFrame(Model_KNN_prediction_test)

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(KNN_result_train['Min Temp 0 C'],KNN_result_train['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(KNN_result_train['Min Temp 0 C'],KNN_result_train['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(KNN_result_test['Min Temp 0 C'],KNN_result_test['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Test")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(KNN_result_test['Min Temp 0 C'],KNN_result_test['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Test")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %% [markdown]
# # Support vector machine (SVM) Model

# %%
from sklearn.svm import SVR

# %%
x_train_SVM, x_test_SVM, y_train_SVM, y_test_SVM = x_train.values, x_test.values, y_train.values.ravel(), y_test.values.ravel()

# %%
Model_SVM = SVR(kernel='rbf')
Model_SVM.fit(x_train_SVM,y_train_SVM)
# Out:
# SVR()

# %%
Model_SVM_prediction_test = Model_SVM.predict(x_test_SVM)
Model_SVM_prediction_train = Model_SVM.predict(x_train_SVM)

# %% [markdown]
# # Support vector machine (SVM) Model Accuracy Check

# %%
Model_SVM_rmse_train = np.sqrt(mean_squared_error(y_train, Model_SVM_prediction_train))
Model_SVM_rmse_train
# Out:
# 120.1081823096767

# %%
Model_SVM_rmse_test = np.sqrt(mean_squared_error(y_test, Model_SVM_prediction_test))
Model_SVM_rmse_test
# Out:
# 120.12110566517097

# %%
Model_SVM_r2_train = r2_score(y_train, Model_SVM_prediction_train)
Model_SVM_r2_train
# Out:
# 0.6541391612277299

# %%
Model_SVM_r2_test = r2_score(y_test, Model_SVM_prediction_test)
Model_SVM_r2_test
# Out:
# 0.6583490721338955

# %%
SVM_result_train = data.iloc[training_index[0]]
SVM_result_train = SVM_result_train.reset_index(drop = True)
SVM_result_train['Predicted Rainfall (mm)'] = pd.DataFrame(Model_SVM_prediction_train)

SVM_result_test = data.iloc[testing_index[0]]
SVM_result_test = SVM_result_test.reset_index(drop = True)
SVM_result_test['Predicted Rainfall (mm)'] = pd.DataFrame(Model_SVM_prediction_test)

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(SVM_result_train['Min Temp 0 C'],SVM_result_train['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(SVM_result_train['Min Temp 0 C'],SVM_result_train['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(SVM_result_test['Min Temp 0 C'],SVM_result_test['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Test")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(SVM_result_test['Min Temp 0 C'],SVM_result_test['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Test")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor
x_train_RF, x_test_RF, y_train_RF, y_test_RF = x_train.values, x_test.values, y_train.values.ravel(), y_test.values.ravel()

# %%
#find out best max depth for RF
i =1
cod = 0
j =1

while (i<=20):
        regressor = RandomForestRegressor(n_estimators = 400,criterion='mse',random_state = 0,max_depth= 20,bootstrap =True)
        regressor.fit(x_train_RF, y_train_RF)
        y_pred_test = regressor.predict(x_test_RF)
        r2 = r2_score(y_test_RF, y_pred_test)
        if r2>cod :
            j = i
        i += 1
print("\ best max depth is: ", j)
# Out:
# \ best max depth is:  20

# %%
Model_RF = RandomForestRegressor(n_estimators = 350,criterion='mse',random_state = 0,max_depth= 20,bootstrap =True)
# fit the regressor with x and y data
Model_RF.fit(x_train_RF, y_train_RF)
# Out:
# RandomForestRegressor(max_depth=20, n_estimators=350, random_state=0)

# %%
Model_RF_prediction_test = Model_RF.predict(x_test_RF)
Model_RF_prediction_train = Model_RF.predict(x_train_RF)

# %% [markdown]
# # Random Forest Model Accuracy Check

# %%
Model_RF_rmse_train = np.sqrt(mean_squared_error(y_train, Model_RF_prediction_train))
Model_RF_rmse_train
# Out:
# 38.65658358718715

# %%
Model_RF_rmse_test = np.sqrt(mean_squared_error(y_test, Model_RF_prediction_test))
Model_RF_rmse_test
# Out:
# 99.57908779647752

# %%
Model_RF_r2_train = r2_score(y_train, Model_RF_prediction_train)
Model_RF_r2_train
# Out:
# 0.9641736025534329

# %%
Model_RF_r2_test = r2_score(y_test, Model_RF_prediction_test)
Model_RF_r2_test
# Out:
# 0.765209646573053

# %%
RF_result_train = data.iloc[training_index[0]]
RF_result_train = RF_result_train.reset_index(drop = True)
RF_result_train['Predicted Rainfall (mm)'] = pd.DataFrame(Model_RF_prediction_train)

RF_result_test = data.iloc[testing_index[0]]
RF_result_test = RF_result_test.reset_index(drop = True)
RF_result_test['Predicted Rainfall (mm)'] = pd.DataFrame(Model_RF_prediction_test)

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(RF_result_train['Min Temp 0 C'],RF_result_train['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(RF_result_train['Min Temp 0 C'],RF_result_train['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Training")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.scatter(RF_result_test['Min Temp 0 C'],RF_result_test['Rainfall (mm)'])
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Actual Rainfall- Test")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Actual Rainfall (mm)")
plt.subplot(1, 2, 2)
plt.scatter(RF_result_test['Min Temp 0 C'],RF_result_test['Predicted Rainfall (mm)'],color = "skyblue")
plt.axis([0, 30, -100, 1000])
plt.title("Minimum Temp vs Predicted Rainfall- Test")
plt.xlabel("Min Temp 0 C")
plt.ylabel("Predicted Rainfall (mm)")
plt.show()

# %%
ML_Models = ["Multiple Linear regression","Polynomial regression","Decision Tree model","k-nearest neighbors","Support vector machine (SVM)","Random Forest model"]
r2 = [Model_MLR_r2_test,Model_PLR_r2_test,Model_DT_r2_test,Model_KNN_r2_test,Model_SVM_r2_test,Model_RF_r2_test] 
rmse = [Model_MLR_rmse_test,Model_PLR_rmse_test,Model_DT_rmse_test,Model_KNN_rmse_test,Model_SVM_rmse_test,Model_RF_rmse_test]

# %% [markdown]
# # Project Results

# %%
result = pd.DataFrame(list(zip(ML_Models,r2,rmse)),columns =['ML Model','R2 Score','RMSE Score'])
print("Summery of the project is as follows: \n")
result
# Out:
# Summery of the project is as follows:
#                        ML Model  R2 Score  RMSE Score
# 0    Multiple Linear regression  0.668746  118.279218
# 1         Polynomial regression  0.763958   99.844203
# 2           Decision Tree model  0.728216  107.137124
# 3           k-nearest neighbors  0.747236  103.320216
# 4  Support vector machine (SVM)  0.658349  120.121106
# 5           Random Forest model  0.765210   99.579088

# %%
c = ['mediumvioletred','darkseagreen','cadetblue','mediumpurple','cornflowerblue','chocolate']
plt.figure(figsize=(10, 8))
plt.bar(ML_Models, r2, width=0.5,color=c)

plt.xlabel('Machine Learning Algorithms')

plt.ylabel('Accuracy Scores')

plt.title('Machine Learning Algorithms R2 Score Chart')

plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
c = ['orchid','mediumvioletred','cadetblue','chocolate','mediumpurple','tan']
plt.figure(figsize=(10, 8))
plt.bar(ML_Models, rmse, width=0.5,color=c)

plt.xlabel('Machine Learning Algorithms')

plt.ylabel('Accuracy Scores')

plt.title('Machine Learning Algorithms RMSE Score Chart')

plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
